# %%
import geopandas as gpd

# %%
edges = gpd.read_file('Data/shipping/nodes/New Shape/edges.shp')
nodes = gpd.read_file('Data/shipping/nodes/New Shape/nodes.shp')

# %%
edges.plot()
# Out:
# <AxesSubplot:>

# %%
nodes.plot()
# Out:
# <AxesSubplot:>
