# %%
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import plotly.graph_objs as go
import pandas as pd
import numpy as np

# %%
total_cost = pd.read_csv('Results/mc/30,-95__2030__100__alkaline__True__1000__Pipe/total_cost_per_kg_h2.csv')
df = pd.read_csv('Results/final_df.csv', index_col=0)


total_cost.iloc[:,3772] = None
total_cost.iloc[:,3978] = None
total_cost.iloc[:,3960] = None
total_cost.iloc[:,5536] = None
total_cost.iloc[:,4548] = None
total_cost.iloc[:,2541] = None
total_cost.iloc[:,3] = None
total_cost.iloc[:,3185] = None

# %%
total_cost.loc['mean', :] = total_cost.mean()
total_cost
# Out:
#       1.034071936628991573e+01  1.027178354946103944e+01  \
# 0                    10.798606                 10.729411
# 1                    10.771842                 10.701029
# 2                    11.463597                 11.385852
# 3                    11.519044                 11.779249
# 4                    10.331921                 10.262043
# ...                        ...                       ...
# 995                  12.078356                 12.192094
# 996                  10.588516                 10.518207
# 997                  11.662300                 11.937681
# 998                  11.290213                 11.215882
# mean                 11.267190                 11.413897
#
#       8.558142463212242035e+00 7.696906577026190632e+00  \
# 0                     9.194266                     None
# 1                     9.079581                     None
# 2                     9.149985                     None
# ...

# %%
best = np.nanmin((total_cost.mean()))


for i,d in total_cost.loc['mean'].items():
    if total_cost.loc['mean', i] == best:
        location = total_cost.columns.get_loc(i)
        
total_cost.loc['mean', :] = total_cost.mean()

best = np.nanmin((total_cost.mean()))
print(best)


for i,d in total_cost.loc['mean'].items():
    if total_cost.loc['mean', i] == best:
        location = total_cost.columns.get_loc(i)

print(location)


df.iloc[location]
# Out:
# 7.594293762860177
# 303
# Longitude                              -104.0
# Latitude                                 27.0
# Solar Energy Potential            1952.384992
# Wind Power Density                  92.117035
# Port Code                                2705
# Port Long.                        -106.404145
# Port Lat.                           23.197825
# Gen-Port Direct Dist.              485.970456
# Gen-Port Driving Dist.               693.9556
# Solar Array Size               1593152.874307
# Solar CapEx                 1115207012.014776
# Wind Turbine Power                   0.289394
# No. of Turbines                   1791.355734
# Wind CapEx                  4514216448.623701
# Yearly Cost Solar            121199336.455959
# Yearly Cost Wind             484666498.487675
# Elec Cost Solar                     38.965238
# Elec Cost Wind                     155.818884
# Cheaper source                          Solar
# Yearly gen. cost             315739039.230783
# ...

# %%
gen_cost.loc['mean', :] = gen_cost.mean()
gen_cost.loc['stddev', :] = gen_cost.std()
gen_cost.iloc[:,3771] = None
gen_cost.iloc[:,3977] = None
gen_cost.iloc[:,3959] = None
gen_cost.iloc[:,5138] = None

best = np.nanmin((gen_cost.mean()))


for i,d in gen_cost.loc['mean'].items():
    if gen_cost.loc['mean', i] == best:
        location = gen_cost.columns.get_loc(i)
        
gen_cost.loc['mean', :] = gen_cost.mean()

best = np.nanmin((gen_cost.mean()))
#print(best)


for i,d in gen_cost.loc['mean'].items():
    if gen_cost.loc['mean', i] == best:
        location = gen_cost.columns.get_loc(i)

print(gen_cost.iloc[1000, 3184])
print(gen_cost.iloc[999, 3184])
print(3184)

worst = np.nanmax(gen_cost.mean())
print(worst)

gen_cost.loc['mean', :] = gen_cost.mean()
gen_cost.iloc[:,3771] = None


for i,d in gen_cost.loc['mean'].items():
    if gen_cost.loc['mean', i] == worst:
        location2 = gen_cost.columns.get_loc(i)
        
gen_cost.loc['mean', :] = gen_cost.mean()

worst = np.nanmax(gen_cost.mean())


for i,d in gen_cost.loc['mean'].items():
    if gen_cost.loc['mean', i] == worst:
        location2 = gen_cost.columns.get_loc(i)


print(location2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5368/1381478688.py in <module>
# ----> 1 gen_cost.loc['mean', :] = gen_cost.mean()
#       2 gen_cost.loc['stddev', :] = gen_cost.std()
#       3 gen_cost.iloc[:,3771] = None
#       4 gen_cost.iloc[:,3977] = None
#       5 gen_cost.iloc[:,3959] = None
#
# NameError: name 'gen_cost' is not defined

# %%
solar_cost.loc['mean', :] = solar_cost.mean()
solar_cost.loc['stddev', :] = solar_cost.std()
solar_cost.iloc[:,3771] = None
solar_cost.iloc[:,3977] = None
solar_cost.iloc[:,3959] = None
solar_cost.iloc[:,5138] = None

best = np.nanmin((solar_cost.mean()))


for i,d in solar_cost.loc['mean'].items():
    if solar_cost.loc['mean', i] == best:
        location = solar_cost.columns.get_loc(i)
        
solar_cost.loc['mean', :] = solar_cost.mean()

best = np.nanmin((solar_cost.mean()))
#print(best)


for i,d in solar_cost.loc['mean'].items():
    if solar_cost.loc['mean', i] == best:
        location = solar_cost.columns.get_loc(i)

print(solar_cost.iloc[1000, 3184])
print(solar_cost.iloc[999, 3184])
print(3184)

worst = np.nanmax(solar_cost.mean())
print(worst)

solar_cost.loc['mean', :] = solar_cost.mean()
solar_cost.iloc[:,3771] = None


for i,d in solar_cost.loc['mean'].items():
    if solar_cost.loc['mean', i] == worst:
        location2 = solar_cost.columns.get_loc(i)
        
solar_cost.loc['mean', :] = solar_cost.mean()

worst = np.nanmax(solar_cost.mean())


for i,d in solar_cost.loc['mean'].items():
    if solar_cost.loc['mean', i] == worst:
        location2 = solar_cost.columns.get_loc(i)


print(location2)

# %%
wind_cost.loc['mean', :] = wind_cost.mean()
wind_cost.loc['stddev', :] = wind_cost.std()
wind_cost.iloc[:,3771] = None
wind_cost.iloc[:,3977] = None
wind_cost.iloc[:,3959] = None
wind_cost.iloc[:,5138] = None

best = np.nanmin((wind_cost.mean()))


for i,d in wind_cost.loc['mean'].items():
    if wind_cost.loc['mean', i] == best:
        location = wind_cost.columns.get_loc(i)
        
wind_cost.loc['mean', :] = wind_cost.mean()

best = np.nanmin((wind_cost.mean()))
#print(best)


for i,d in wind_cost.loc['mean'].items():
    if wind_cost.loc['mean', i] == best:
        location = wind_cost.columns.get_loc(i)

print(wind_cost.iloc[1000, 3184])
print(wind_cost.iloc[999, 3184])
print(3184)

worst = np.nanmax(wind_cost.mean())
print(worst)

wind_cost.loc['mean', :] = wind_cost.mean()
wind_cost.iloc[:,3771] = None


for i,d in wind_cost.loc['mean'].items():
    if wind_cost.loc['mean', i] == worst:
        location2 = wind_cost.columns.get_loc(i)
        
wind_cost.loc['mean', :] = wind_cost.mean()

worst = np.nanmax(wind_cost.mean())


for i,d in wind_cost.loc['mean'].items():
    if wind_cost.loc['mean', i] == worst:
        location2 = wind_cost.columns.get_loc(i)


print(location2)

# %%
print('wind power average: ')
print(wind_cost.mean().mean())

print('solar power average: ')
print(solar_cost.mean().mean())
